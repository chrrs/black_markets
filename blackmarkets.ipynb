# %% [markdown]
# # Introduction to Digital Forensics - **Assignment 1**
#
# By Beatrice Beretta (s2584891), Rodrigo Carvalho (s2379821), Alison Brandt (s2367815), Chris Bleeker (s2462648), Allen Sirkin (s2293153) and Julia Naastepad (s2483068)
#
# ## Introduction and motivation
#
# The goal of this analysis is to gain a better understanding of the black market. This ranges from seeing what kind of items and services are being offered, the general price ranges, the different sellers and their inventories, and what items we find most surprising. In addition to this we will attempt to classify the legality of the items identified. Finally, we will show who we believe are the top sellers from the investigated sites in order as well as who are the top three sellers who should be investigated by the police.

# %% [markdown]
# ## Methodology
#
# We used the site https://darknetone.com/markets/ to find a list of black markets located on the dark web. We acessed these websites using the Tor Browser, because they aren't accessible using your normal web browser. Some of the black markets required us to have a registered account. If this happened, we simply created a temporary throwaway account with no leads back to our real identities.
#
# Once we entered the black markets, we started browsing. We chose a random, but diverse list of items from the websites, and put them in the table, filling in the appropriate columns. In one of these columns, we noted down if we thought the _selling_ of these products is illegal, which we discussed in our group. If the legality is questionable, we put our reasoning why it could be illegal or legal in the additional notes column.
#
# While going through the posts, we select some of the posts we have chosen, and look at the seller. We look at some relevant information about the seller and put it in another table.
#
# To determine the top 10 sellers, we look at their amount of posts and the lowest cost to calculate what minimum revenue they would generate if each post would sell once. In addition to this we determine the top 3 sellers we believe should be investigated further based on how much harm their items can cause to other people.
#
# Since these results are random by nature, repeating this analysis wouldn't give exactly the same results, but still very similar. There is a bit of objectivity in the Legality column, because this is based on how you interpret the law.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Import the required libaries

# %%
import pandas as pd

# Display all table entries fully.
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Import and show the posts table

# %%
df = pd.read_csv('posts.csv')

# We sort the list by category, seller and then price
df = df.sort_values(by=['Category', 'Site', 'Seller'])

# Reset the index column
df.reset_index(drop = True, inplace = True)
df
# Out:
#                                                                                         Title  \
# 0                                            Ipvanish Vpn Account[LIFETIME]★★ Auto Delivery★★
# 1                                                           -== Spotify PREMIUM Accounts ==-
# 2                                                         -== Skillshare Premium Account ==-
# 3                                                               Slovenia Fake Driving License
# 4                                        75x counterfeit 20 dollar bills 1500 for 400 dollars
# 5                    Ladies Rolex DateJust Model 179174 1:1 Replica. Identical to Original A+
# 6                                               Rolex - GMT‑Master II ALL Ice S【UltimateAAA+】
# 7                                     Audemars Piguet - Royal Oak 15400 Rose Gold Black 5000$
# 8              100X 50 EURO | Fake Notes | ++All Security Marks++ | Counterfeit Notes Germany
# 9                                          Walgreens Pharmacy Prescription Label PSD Template
# 10                                                   ♔ Forged University of Houston Diploma ♔
# 11                                                       ♔ Forged Xfinity Comcast Statement ♔
# 12  *SALE* AUDEMARS PIGUET - Royal Oak SELF-WINDING 15500ST. 1:1 Perfect Replica - SUPERCLONE
# 13                    *SALE* ROLEX SEA DWELLER DEEP SEA MODEL 116660. 1:1 Perfect Replica A++
# 14                                                                                   Passport
# 15                                       *RARE* Replica Jordan 1 Retro High Off-White Chicago
# 16                                                                  1:1 Replica HERMÈS BIRKIN
# 17                                                                  8G CRYSTAL METH TOP SHELF
# 18                                                     Heroin Black Tar Fent - Free! 3 Grams
# 19                                                                         HIGH GRADE HEROIN
# 20                                             14g Magic Mushrooms - Whole Psilocybe Cubensis
# 21                                     *INTRO OFFER* 1000x BUDHEADS (WORMS) 600MG THC-EDIBLES
# 22                                                                             15g Lemon Haze
# 23                                              20GR High Quality AFGHAN Heroine #3 UNCUT 90%
# 24                        1000 Grams (1KG) Cocaina Colombiana "FRESH NOSE" PURE UNCUT COCAINE
# 25                                                               CAMEL FLAVORED TOBBACO (30g)
# 26                                                 Adderall DP30 Prescription Grade Promo x50
# 27                                                            CREDIT CARD 10-18K !! 100% SAFE
# 28                                   !! Amazon gift card 5x100 $ !! 100% sure !! 100% live !!
# 29                              1:1 Replica APPLE AirPods with Charging Case (2nd generation)
# 30                                                                    1:1 Replica AirPods MAX
# 31                                       POLISH ID SCAN HQ SCANS FROM REAL PERSONS both sides
# 32                               Packstation DHL Account | Anonyme Packstation | HQ | Germany
# 33                                                         Ohio Voter Database 7509310 Voters
# 34                                                           California Birth Index 1905-1995
# 35                                                $30K-$35K CREDIT CARD+PIN+CHECKER[100%LIVE]
# 36                                               2000$ US Paypal Accounts Balance - PP Credit
# 37                                                                      SSN CARD TEMPLATE USA
# 38           Guide Counterfeit Money Making How to Make $100 Bills -INSTANT DELIVERY + BONUS
# 39                                                   How to create a new fake identity (2021)
# 40                                            How To Get Free Amazon Prime - Instant Delivery
# 41                                                       HOW TO BACKDOOR AN APP TO SPY ANYONE
# 42                                      YOUTUBE: How To Become Rich || HQ eBook With ECourses
# 43                             990K Combolist EmailPass Gaming Streaming and other by Robbin
# 44                                                          65 PAGE FULL REFUND BIBLE PACKAGE
# 45                                                                      Create DROP ADDRESSES
# 46                                                                 GOLD BARS AMD GOLD NUGGETS
# 47                                                                               Sample pack
# 48                                                                          1 ounce of silver
# 49                                      CRYPTO TREND MANIPULATION and CLICK FARMING OFFERING.
# 50                                                 0,23 Million United Kingdom Mobile Numbers
# 51                                                             Twitch Followers | 1000 For 6$
# 52                                                EMAIL BOMBER FLOODER SPAM SPAMMING SERVICE
# 53                                             1000 Instagram Followers $4 CHEAPEST ON MARKET
# 54                                                                PASSWORD CRACKER [ZIP FILE]
# 55                                                  WhatsApp Pishing (The Ultimate Software)
# 56                          Latest Android Malware with Rooting Abilities Can Wipe Your Data
# 57                                                          Mining Botnet | Instant Delivery
# 58                                               Bruteforce Softwares For Hacking Any Account
# 59                                                         Ransomware Money (Make $10k/month)
# 60                                                                    Glock 17 3d Printer Gun
# 61                                                     3D Printed GUN Blueprints [Undetectabl
# 62                                                                        3D Weapon Mega Pack
# 63                                              BEST GRADES COUNTERFEIT NOTES USD,EURO,POUNDS
# 64                          ID CARD/ CERTIFICATES /PASSPORTS/ DRIVER LICENSE/Resident permit/
# 65           Constructor for mephedrone (4-mmc). Self-brominated kits at 4MPF. Per 100 grams.
# 66                                    clone and Prepaid cards and debit cards available $5000
# 67                          How To Make Drugs (Tutorials Pack) 587mb total - Instant Delivery
# 68                           How to Bypass Netflix Phone Verification - 100% Working Method -
# 69                                BTC BlackMailer - Make Millions Remotely - Instant Delivery
# 70                            Hack Mega Pack: Rats, Keylogger, Cracks More --instant Delivery
# 71                                              3D-Printed GUN Blueprints (LIBERATOR ®) v 1.0
#
#                  Price     Category              Seller  Legality  \
# 0                $3.50     Accounts         bulkversion   Depends
# 1                $2.99     Accounts        digitalworld   Illegal
# 2                $4.99     Accounts        digitalworld   Illegal
# 3              $174.05  Counterfeit        fakeideurope   Illegal
# 4              $402.00  Counterfeit          fraudbuddy   Illegal
# 5              $150.40  Counterfeit      thejuicedoctor   Depends
# 6              $600.00  Counterfeit           sexyhomer   Illegal
# 7            $5,000.00  Counterfeit          stevemeds1   Illegal
# 8               $79.96  Counterfeit          Rammstein   Illegal
# 9               $24.99  Counterfeit           GoldApple   Illegal
# 10             $100.00  Counterfeit        namedeclined   Illegal
# 11              $50.00  Counterfeit        namedeclined   Illegal
# 12             $276.35  Counterfeit      thejuicedoctor   Depends
# 13             $288.54  Counterfeit      thejuicedoctor   Depends
# 14             $600.00  Counterfeit               ytuiv   Illegal
# 15             $250.00  Counterfeit               Hazzy     Legal
# 16             $250.00  Counterfeit               Hazzy   Depends
# 17             $176.90        Drugs       CaesarsPalace   Illegal
# 18             $201.00        Drugs           Safeserve   Illegal
# 19             $201.00        Drugs         dopekingusa   Illegal
# 20             $128.60        Drugs      themushroomman   Illegal
# 21           $7,537.89        Drugs           sweetyman   Illegal
# 22             $170.00        Drugs          TheSpecial   Illegal
# 23             $554.00        Drugs       TheodorMorell   Illegal
# 24          $68,445.00        Drugs           drugshub1   illegal
# 25              $10.00        Drugs         Prosperity1   Illegal
# 26       $170 for 50p.       Drugs        Freewaybogez    Illegal
# 27              $10.18  Electronics      HappyShopOrigi   Illegal
# 28              $33.94  Electronics       SpongebobShop   Illegal
# 29              $65.00  Electronics               Hazzy   Depends
# 30             $120.00  Electronics               Hazzy   Depends
# 31              $15.10        Fraud            drhack3r   Illegal
# 32              $72.82        Fraud           Rammstein   Depends
# 33               $9.99        Fraud           GoldApple   Illegal
# 34               $9.99        Fraud           GoldApple   Illegal
# 35              $13.70        Fraud      HappyShopOrigi   Depends
# 36              $16.00        Fraud               Rambe   Illegal
# 37              $10.00        Fraud           topkittzz   Illegal
# 38              $10.05        Guide       smart666tiger   Depends
# 39               $2.05        Guide           superhero   Depends
# 40               $2.49        Guide           Legendary   Depends
# 41               $4.00        Guide            Onepiece   Depends
# 42               $3.50        Guide       DarknetWizard   Depends
# 43               $3.00        Guide            katarina   Illegal
# 44        CAD $75.0225        Guide               joker   Depends
# 45             CAD $21        Guide         lordfinnese   Depends
# 46              $50.04       Metals          futuremeds   Depends
# 47  1$ per single bill       Metals          anonsheep    Illegal
# 48             CAD $63       Metals       gracepapineau   Depends
# 49          $50,251.05     Services          fraudbuddy   Illegal
# 50               $9.99     Services           GoldApple   Depends
# 51               $6.00     Services         socialmedia   Depends
# 52           CAD $7.35     Services         canadapilot   Depends
# 53           CAD $4.20     Services     thepirateisland   Depends
# 54               $5.95     Software      HappyShopOrigi   Depends
# 55               $2.99     Software     DangerousTomato   Depends
# 56               $1.36     Software      heartkidnapper   Depends
# 57               $9.86     Software           topkittzz   Depends
# 58        CAD $20.9895     Software             pegasus   Illegal
# 59             CAD $63     Software  thedangeroustomato   Depends
# 60              $10.00      Weapons    Napoleonbonapart   Illegal
# 61               $2.99      Weapons  TheDangerousTomato   Depends
# 62              $25.00      Weapons       TheFreelancer   Depends
# 63             $500.00  counterfeit         timmiroll56   Illegal
# 64           $1,000.00  counterfeit         timmiroll56   Illegal
# 65             $400.00        drugs              seller   Illegal
# 66             $600.00        fraud         timmiroll56   Illegal
# 67               $2.99        guide         HarleyQuinn   Depends
# 68               $2.99     software         HarleyQuinn   Illegal
# 69               $2.99     software         HarleyQuinn   Depends
# 70               $3.99     software         HarleyQuinn   Depends
# 71               $2.99      weapons         HarleyQuinn   Illegal
#
#                                                                                                                       Additional Notes  \
# 0                                                                                                    illegal if the account was stolen
# 1                                                                              account accessed without consent from the account owner
# 2                                                                              account accessed without consent from the account owner
# 3                                                                                                                                  NaN
# 4                                                                          Money laundering - Trading counterfeit money for real money
# 5   It's clearly stated that it's counterfeit, but the intention may be to resell it as real. Also it might be copyright infringement.
# 6                                     advertises that it comes with Rolex box and certificate, but at price point it is fake-copyright
# 7                                                                        advertises as a real Audemars but is a reproduction-copyright
# 8                                                                                                                     Money Laudering
# 9                                                                                     allows false prescriptions to be filled, i think
# 10                                                                                made-to-order university diploma bachelor,master,phD
# 11                                                                      fake cable bill that can be used for proof of address/spending
# 12                                                             advertises as replica but customer would likely present it as real item
# 13                                         advertises as replica but comes with the box and certificates authenticating its legitimacy
# 14                                                                           reproduced passport for a variety of countries on request
# 15                                                      advertised as a replica, but customer could intent to resell it as a real item
# 16                                                      advertised as a replica, but customer could intent to resell it as a real item
# 17                                                                                                                                 NaN
# 18                                                                                                                                 NaN
# 19                                                                                                                                 NaN
# 20                                                                                                                                 NaN
# 21                                                                                                                                 NaN
# 22                                                                                                                               drugs
# 23                                                                                                                                 NaN
# 24                                                                                                                                 NaN
# 25                                                                                                                                 NaN
# 26                                            Adderall cannot be sold without prescription for ADHD/ADD or other types of pathologies
# 27                                                                                              credit card with fake name and address
# 28                                                                 advertises that the codes for the cards are sent via chat-copyright
# 29                                        patent infringement but labelled as replica, customer would likely present it as a real item
# 30                                                      advertised as a replica, but customer could intent to resell it as a real item
# 31                                                                                                                                 NaN
# 32                                                    - depends on the intention; Owning one isnt setting it up to steal packages is.
# 33                                   voters did not consent for this information to be sold (and there is a LOT of information listed)
# 34                                 birth records sold without people's consent, can be used to reissue identity documents fraudulently
# 35                                                                                    large limit credit card available for a pittance
# 36                                                  Appears to be using an established account w/o owners consent based on description
# 37                                                                              photoshop template for customer to fill with bogus SSN
# 38                                                                                       depends on the methods used to make the money
# 39                                                                      illegal if you intent to follow it to try to escape the police
# 40                                                                  guide itself may not be illegal but the methods illustrated may be
# 41                                                                 guide itself may not be illegal but the use afterwards of spying is
# 42                                                                                 could be illegal depending on the methods presented
# 43     emails are personally identifiable information, for which no consent is given by the owners of the email addresses to be shared
# 44                      a guide on its own wouldnt be illegal, guide on how to refund ordered items while keeping and seeling the item
# 45                          just knowing how towouldn't be illegal, guide on how to set up drop adresses for purchases on black market
# 46                                      depends on the source of the gold. also weird that the product description only included drugs
# 47                                      You cannot use those to make your own sample packs and distribute them, commercially or free.
# 48                                                               depends of the source of the silver, obviously illegal if it's stolen
# 49                                                                                                                  Market maniplation
# 50                               numbers, if legitimate, were not given with users consent. probably used for farming data or phishing
# 51                                    if the followers are actual accounts then it's done without accountholder's consent, most likely
# 52                                                                            legal if done to self, sends 1000 emails where requested
# 53                                                          against the terms of service, could be illegal if stolen accounts are used
# 54                         Brute forcing a password is illegal but if for the purposes of testing with the person's consent perhaps ok
# 55                                                                   its illegal if you use it on people without getting their consent
# 56                                                       depends if the buyer intends to actually use it for malicious purposes or not
# 57                                                       depends if the buyer intends to spread it to computers without consent or not
# 58                                                                                                                                 NaN
# 59                          if never used on an unconcenting person then it should be ok, code and instructions for ransomware attacks
# 60                                                                                                             unlicensed gun sellling
# 61                                                                    illegal if the customer actually decides to make and use the gun
# 62                                                                    illegal if the customer actually decides to make and use the gun
# 63                                                                                                                                 NaN
# 64                                                                                                                                 NaN
# 65                                                                                                             set for producing drugs
# 66                                                                                                                                 NaN
# 67                                                                                           legal as long as you don't make any drugs
# 68                                                                                                                                 NaN
# 69                                                                             if not use on non-concenting party than it should be ok
# 70                                                                                      legal as long as you use the code consensually
# 71                                                                                                                                 NaN
#
#                Site
# 0       ASAP market
# 1          Tor2door
# 2          Tor2door
# 3       ASAP market
# 4       ASAP market
# 5       ASAP market
# 6           DarkFox
# 7           DarkFox
# 8          DarkFox
# 9          Tor2door
# 10         Tor2door
# 11         Tor2door
# 12         Tor2door
# 13         Tor2door
# 14         Tor2door
# 15       WeTheNorth
# 16       WeTheNorth
# 17      ASAP market
# 18      ASAP market
# 19      ASAP market
# 20      ASAP market
# 21         DarkFox
# 22        Incognito
# 23        Incognito
# 24        Incognito
# 25       WeTheNorth
# 26  Tor2door Market
# 27          DarkFox
# 28          DarkFox
# 29       WeTheNorth
# 30       WeTheNorth
# 31      ASAP market
# 32          DarkFox
# 33         Tor2door
# 34         Tor2door
# 35         Tor2door
# 36         Tor2door
# 37         Tor2door
# 38      ASAP market
# 39      ASAP market
# 40          DarkFox
# 41          DarkFox
# 42         Tor2door
# 43         Tor2door
# 44       WeTheNorth
# 45       WeTheNorth
# 46          DarkFox
# 47  Tor2door Market
# 48       WeTheNorth
# 49      ASAP market
# 50         Tor2door
# 51         Tor2door
# 52       WeTheNorth
# 53       WeTheNorth
# 54          DarkFox
# 55         Tor2door
# 56         Tor2door
# 57         Tor2door
# 58       WeTheNorth
# 59       WeTheNorth
# 60       WeTheNorth
# 61       WeTheNorth
# 62       WeTheNorth
# 63     Quest Market
# 64     Quest Market
# 65   Courier Market
# 66     Quest Market
# 67              NaN
# 68     Quest Market
# 69     Quest Market
# 70              NaN
# 71       WeTheNorth

# %% [markdown]
# ### Determine the three products that made you the most suprised
#
# Most of the products in the list are pretty ordinary, things you would expect to see on a black market. Then there are a lot of products that fall in categories you wouldn't necessarily expect to see in a black market, but it still appears a lot. Finally, there is a small subgroup of products which even on the black market appear only once or twice. This category contains the three items that we were most suprised by.
#
# Our top three of most suprising posts are:
#
# - **R.A.T. Setup and Mentoring Service - Make Money. Fast. Simple.:** This was surprising because it was not expected that someone on one of the darkmarket sites would be offering to actively teach a person as well as offering to give follow up help for some time after.
# - **YOUTUBE: How To Become Rich || HQ eBook With ECourses:** This post seems peculiar, because if such a guide is uploaded to YouTube, it most likely doesn't contain any illegal methods, since that is against the ToS of YouTube. But if it doesn't contain any illegal methods, why would it be on the black market? What is the difference between this and any other (public) guide or video on YouTube that explains ways on how to get rich.
# - **Forged Xfinity Comcast Statement:** On first sight, this makes no sense. You would think an official statement from Xfinity or Comcast would we useless. But this can actually be used to prove to the respective company that you own, live at or in any other way are affiliated with the address listed on the statement. This can then be used to impersonate the house owner.

# %% [markdown]
# ### Import and show the sellers table

# %%
sf = pd.read_csv('sellers.csv')

# Sort by the amount of posts and rating
sf = sf.sort_values(by = ['Amount of posts'], ascending = False)

# Reset the index column
sf.reset_index(drop = True, inplace = True)
sf
# Out:
#                   Name  Amount of posts      Rating  Low price ($)  \
# 0      DangerousTomato             2235         64%           2.00
# 1          prettypacks             1667         99%          50.00
# 2          HarleyQuinn              450  no reviews           1.00
# 3          timmiroll56              415        100%         500.00
# 4                g3cko              282        100%           1.00
# 5             Fraudway              251        100%           1.72
# 6           fraudbuddy              187         80%          50.00
# 7            GoldApple              150         94%           1.00
# 8         trusteelucky              148         96%          10.00
# 9       HappyShopOrigi              121         80%           1.00
# 10        digitalworld              120         94%           3.00
# 11  thedangeroustomato              100         98%           6.00
# 12         biochemshop               97         91%           8.00
# 13        namedeclined               78        100%          20.00
# 14      thejuicedoctor               62         99%         150.00
# 15         lordfinnese               42         93%          20.00
# 16       gracepapineau               38         98%           7.00
# 17     thepirateisland               38        100%           7.00
# 18             pegasus               37         85%          10.00
# 19               joker               17         91%          10.00
# 20              seller               12         50%           0.01
# 21         canadapilot                5        100%           7.00
#
#     High price ($)               Primary category            Site
# 0                5             Fraud and Software        Tor2door
# 1              500                          Drugs     ASAP market
# 2               45             software and guids    Quest Market
# 3             2000   counterfeit, fraud and drugs    Quest Market
# 4              990            software and guides    Quest Market
# 5              387            software and guides    Quest Market
# 6            50000                    Counterfeit     ASAP market
# 7               25             Fraud and Software        Tor2door
# 8              100                fraud and guids    Quest Market
# 9               20             Fraud and Software        Tor2door
# 10              10          Software and accounts        Tor2door
# 11              52                fraud and guids      WeTheNorth
# 12           10000          counterfeit and drugs    Quest Market
# 13             800         Fraud, Software, Drugs        Tor2door
# 14             250                    Counterfeit     ASAP market
# 15             727                fraud and guids      WeTheNorth
# 16            1000                fraud and guids      WeTheNorth
# 17             315  digital products and services      WeTheNorth
# 18             103      fraud, software and guids      WeTheNorth
# 19            1050                fraud and guids      WeTheNorth
# 20            3000         porn and illegal items  Courier Market
# 21              52                       services      WeTheNorth

# %% [markdown]
# ### Determine the top 10 sellers

# %%
sf['Estimated revenue'] = sf['Amount of posts'] * sf['Low price ($)']
top10 = sf.sort_values(by = ['Estimated revenue'], ascending = False)
top10 = top10.head(10)
top10.reset_index(drop = True, inplace = True)
top10
# Out:
#                  Name  Amount of posts Rating  Low price ($)  High price ($)  \
# 0         timmiroll56              415   100%          500.0            2000
# 1         prettypacks             1667    99%           50.0             500
# 2          fraudbuddy              187    80%           50.0           50000
# 3      thejuicedoctor               62    99%          150.0             250
# 4     DangerousTomato             2235    64%            2.0               5
# 5        namedeclined               78   100%           20.0             800
# 6        trusteelucky              148    96%           10.0             100
# 7         lordfinnese               42    93%           20.0             727
# 8         biochemshop               97    91%            8.0           10000
# 9  thedangeroustomato              100    98%            6.0              52
#
#                Primary category          Site  Estimated revenue
# 0  counterfeit, fraud and drugs  Quest Market           207500.0
# 1                         Drugs   ASAP market            83350.0
# 2                   Counterfeit   ASAP market             9350.0
# 3                   Counterfeit   ASAP market             9300.0
# 4            Fraud and Software      Tor2door             4470.0
# 5        Fraud, Software, Drugs      Tor2door             1560.0
# 6               fraud and guids  Quest Market             1480.0
# 7               fraud and guids    WeTheNorth              840.0
# 8         counterfeit and drugs  Quest Market              776.0
# 9               fraud and guids    WeTheNorth              600.0

# %% [markdown]
# ### Determine which 3 sellers should be reported to the police
#
# Fraud and counterfeit could be very harmful to others, so the worst sellers probably sell products in this category. Malware is also a big thing which could lead to fraud.
#
# The 3 sellers which sell the most of these products and thus we think should be reported to the police are:
# - **timmiroll56** on Quest Market
# - **DangerousTomato** on Tor2door
# - **namedeclined** on Tor2door
#
# We believe that these are the worst sellers within our results. Shutting down these sellers would remove a lot of fraud from the black market, which in turn makes it so that less people are victim of fraud.

# %% [markdown]
# # Conclusion
#
# In conclusion, we have found a very wide selection of different items in very different price ranges from an assortment of sellers that seem to specialize in multiple categories, with the most surprising ones being the things that seemed to be the most out of place. The black markets seam to be just be lowly regulated online marketplaces where yo can look for or offer nealy any service and if one site won't allow you to sell what you want you can just find one that will. While not everything sold on the sites are inherantly illegal many things are and most of what isn't is likely to be used illegally.
