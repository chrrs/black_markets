# %% [markdown]
# # Introduction to Digital Forensics - **Assignment 1**
#
# By Beatrice Beretta (s2584891), Rodrigo Carvalho (s2379821), Alison Brandt (s2367815), Chris Bleeker (s2462648), Allen Sirkin (s2293153) and Julia Naastepad (s2483068)
#
# ## Introduction and motivation
#
# The goal of this analysis is to gain a better understanding of the black market. This ranges from seeing what kind of items and services are being offered, the general price ranges, the different sellers and their inventories, and what items we find most surprising. In addition to this we will attempt to classify the legality of the items identified. Finally, we will show who we believe are the top sellers from the investigated sites in order as well as who are the top three sellers who should be investigated by the police.

# %% [markdown]
# ## Methodology
#
# We used the site https://darknetone.com/markets/ to find a list of black markets located on the dark web. We acessed these websites using the Tor Browser, because they aren't accessible using your normal web browser. Some of the black markets required us to have a registered account. If this happened, we simply created a temporary throwaway account with no leads back to our real identities.
#
# Once we entered the black markets, we started browsing. We chose a random, but diverse list of items from the websites, and put them in the table, filling in the appropriate columns. In one of these columns, we noted down if we thought the _selling_ of these products is illegal, which we discussed in our group. If the legality is questionable, we put our reasoning why it could be illegal or legal in the additional notes column.
#
# While going through the posts, we select some of the posts we have chosen, and look at the seller. We look at some relevant information about the seller and put it in another table.
#
# To determine the top 10 sellers, we look at their amount of posts and the lowest cost to calculate what minimum revenue they would generate if each post would sell once. In addition to this we determine the top 3 sellers we believe should be investigated further based on how much harm their items can cause to other people.
#
# Since these results are random by nature, repeating this analysis wouldn't give exactly the same results, but still very similar. There is a bit of objectivity in the Legality column, because this is based on how you interpret the law.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Import the required libaries

# %%
import pandas as pd

# Display all table entries fully.
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Import and show the posts table

# %%
df = pd.read_csv('posts.csv')

# We sort the list by category, seller and then price
df = df.sort_values(by=['Category', 'Site', 'Seller'])

# Reset the index column
df.reset_index(drop = True, inplace = True)
df
# Out:
#                                                                                                                              Title  \
# 0                                                                                 Ipvanish Vpn Account[LIFETIME]★★ Auto Delivery★★
# 1                                                                                                -== Spotify PREMIUM Accounts ==-
# 2                                                                                              -== Skillshare Premium Account ==-
# 3                                                            *COVID-19 Vaccination Record Card CDC USA Authentic Vaccine Passport*
# 4                                                                                                    Slovenia Fake Driving License
# 5                                                                                           Washington New Driver License Hologram
# 6                                                                             75x counterfeit 20 dollar bills 1500 for 400 dollars
# 7                                                                                                             Polish police report
# 8                                                         Ladies Rolex DateJust Model 179174 1:1 Replica. Identical to Original A+
# 9                                                                                    Rolex - GMT‑Master II ALL Ice S【UltimateAAA+】
# 10                                                                         Audemars Piguet - Royal Oak 15400 Rose Gold Black 5000$
# 11                                                  100X 50 EURO | Fake Notes | ++All Security Marks++ | Counterfeit Notes Germany
# 12                                                                             200000 Australian dollar with all security features
# 13                                                                                   BEST GRADES COUNTERFEIT NOTES USD,EURO,POUNDS
# 14                                                               ID CARD/ CERTIFICATES /PASSPORTS/ DRIVER LICENSE/Resident permit/
# 15                                                                              Walgreens Pharmacy Prescription Label PSD Template
# 16                                                                                        ♔ Forged University of Houston Diploma ♔
# 17                                                                                            ♔ Forged Xfinity Comcast Statement ♔
# 18                                       *SALE* AUDEMARS PIGUET - Royal Oak SELF-WINDING 15500ST. 1:1 Perfect Replica - SUPERCLONE
# 19                                                         *SALE* ROLEX SEA DWELLER DEEP SEA MODEL 116660. 1:1 Perfect Replica A++
# 20                                                                                                                        Passport
# 21                                                                            *RARE* Replica Jordan 1 Retro High Off-White Chicago
# 22                                                                                                       1:1 Replica HERMÈS BIRKIN
# 23                                                                                                       8G CRYSTAL METH TOP SHELF
# 24                                                                                          Heroin Black Tar Fent - Free! 3 Grams
# 25                                                                              Pfizer Xanax 0.5mg ( 1000 Tablets ) ( Alprazolam )
# 26                                                                                                              HIGH GRADE HEROIN
# 27                                                                                  14g Magic Mushrooms - Whole Psilocybe Cubensis
# 28                                                Constructor for mephedrone (4-mmc). Self-brominated kits at 4MPF. Per 100 grams.
# 29                                                                          *INTRO OFFER* 1000x BUDHEADS (WORMS) 600MG THC-EDIBLES
# 30                                                                                                                  15g Lemon Haze
# 31                                                                                   20GR High Quality AFGHAN Heroine #3 UNCUT 90%
# 32                                                             1000 Grams (1KG) Cocaina Colombiana "FRESH NOSE" PURE UNCUT COCAINE
# 33                                                                                                    CAMEL FLAVORED TOBBACO (30g)
# 34                                                                                      Adderall DP30 Prescription Grade Promo x50
# 35                                                                                                 CREDIT CARD 10-18K !! 100% SAFE
# 36                                                                        !! Amazon gift card 5x100 $ !! 100% sure !! 100% live !!
# 37                                                                   1:1 Replica APPLE AirPods with Charging Case (2nd generation)
# 38                                                                                                         1:1 Replica AirPods MAX
# 39                              FULL EDITABLE Australia Bank statement, TPG BANK, NAB, ANZ, COMMONWEALTH, BANK of WEST, QUEENSLAND
# 40                                                                            POLISH ID SCAN HQ SCANS FROM REAL PERSONS both sides
# 41                                                                                                     HD lifetime showmax premium
# 42  ||||| Personal Check editable template PSD digital checks very high quality ||||| Make digital checks for mobile deposit |||||
# 43                                          >>> RDP Remote Desktop residential Admin Access <<>>> 100% carding / fraud success <<<
# 44                                                                                           JobStreet Database 16 Million Records
# 45                                                                                  Offshore ANONYMOUS / NONAME PREPAID CARDS link
# 46                                                                                                  HIGH LIMITS BITCOIN DEBIT CARD
# 47       Fake ID DL Arizona w all security features scanable with tracking! BEST PRICE AND BEST QUALITY ★★BULK ORDER = DISCOUNTS★★
# 48                                                                    Packstation DHL Account | Anonyme Packstation | HQ | Germany
# 49                                                                         clone and Prepaid cards and debit cards available $5000
# 50                                                                                              Ohio Voter Database 7509310 Voters
# 51                                                                                                California Birth Index 1905-1995
# 52                                                                                     $30K-$35K CREDIT CARD+PIN+CHECKER[100%LIVE]
# 53                                                                                    2000$ US Paypal Accounts Balance - PP Credit
# 54                                                                                                           SSN CARD TEMPLATE USA
# 55                                                                                On How best to hack Any Gmail Account (Tutorial)
# 56                                                                    The best on how To Hack Passwords Using USB Drive (Tutorial)
# 57                                                Guide Counterfeit Money Making How to Make $100 Bills -INSTANT DELIVERY + BONUS
# 58                                                                                        How to create a new fake identity (2021)
# 59                                     DEEPWEB STARTER MASTERCLASS -ALL KNOWLEDGES, INFOS, ANONYMITY, TUTORIALS, SECURITY INCLUDED
# 60                                                                                              Easy, good and cheap Crack recipe!
# 61                                                                                 How To Get Free Amazon Prime - Instant Delivery
# 62                                                                                            HOW TO BACKDOOR AN APP TO SPY ANYONE
# 63                                                                  R.A.T. Setup and Mentoring Service - Make Money. Fast. Simple.
# 64                                                                                             How To Encode Track Info To Plastic
# 65                                                               How To Make Drugs (Tutorials Pack) 587mb total - Instant Delivery
# 66                                                               Carding in 15mn Safely & Efficiently CC 2 BTC+1 USA CC EXTRA FREE
# 67                                                                           YOUTUBE: How To Become Rich || HQ eBook With ECourses
# 68                                                                  990K Combolist EmailPass Gaming Streaming and other by Robbin
# 69                                                                                               65 PAGE FULL REFUND BIBLE PACKAGE
# 70                                                                                                           Create DROP ADDRESSES
# 71                                                                                                      GOLD BARS AMD GOLD NUGGETS
# 72                                                                                                                    Sample pack
# 73                                                                                                               1 ounce of silver
# 74                                                                           CRYPTO TREND MANIPULATION and CLICK FARMING OFFERING.
# 75                                                                                      0,23 Million United Kingdom Mobile Numbers
# 76                                                                                                  Twitch Followers | 1000 For 6$
# 77                                                                                     EMAIL BOMBER FLOODER SPAM SPAMMING SERVICE
# 78                                                                                  1000 Instagram Followers $4 CHEAPEST ON MARKET
# 79                                                                                                     Caller ID and spoofing tool
# 80                                                                                          CIA forensics expert tool - Magnet IEF
# 81                                                                                                     PASSWORD CRACKER [ZIP FILE]
# 82                                                               SPY NOTE v5.0 - Android Remote Administration Tool - Instant Deli
# 83                                                                  CUTLET MAKER#ATM MALWARE # CRACK ATMS IN AS FAST AS 60 SECONDS
# 84                                                                How to Bypass Netflix Phone Verification - 100% Working Method -
# 85                                                                     BTC BlackMailer - Make Millions Remotely - Instant Delivery
# 86                                                                 Hack Mega Pack: Rats, Keylogger, Cracks More --instant Delivery
# 87                                                                        Premium AI Bot (Binary Option & Forex Scalping Strategy)
# 88                                                                                       Make hudge money on poker - use Poker Spy
# 89                                                                                          Trojan Killer - full cracked version !
# 90                                                                                       WhatsApp Pishing (The Ultimate Software)
# 91                                                               Latest Android Malware with Rooting Abilities Can Wipe Your Data
# 92                                                                                               Mining Botnet | Instant Delivery
# 93                                                                                    Bruteforce Softwares For Hacking Any Account
# 94                                                                                              Ransomware Money (Make $10k/month)
# 95                                                                                   3D-Printed GUN Blueprints (LIBERATOR ®) v 1.0
# 96                                                                                                         Glock 17 3d Printer Gun
# 97                                                                                          3D Printed GUN Blueprints [Undetectabl
# 98                                                                                                             3D Weapon Mega Pack
# 99                                                                               Bitcoin stealing virus 2018 - get unlimited BTC !
#
#                  Price     Category              Seller  Legality  \
# 0                $3.50     Accounts         bulkversion   Depends
# 1                $2.99     Accounts        digitalworld   Illegal
# 2                $4.99     Accounts        digitalworld   Illegal
# 3              $226.15  Counterfeit           dannyboys   Illegal
# 4              $174.05  Counterfeit        fakeideurope   Illegal
# 5               $25.15  Counterfeit          falloutb0y   Depends
# 6              $402.00  Counterfeit          fraudbuddy   Illegal
# 7                $5.05  Counterfeit      misspocahontas   Illegal
# 8              $150.40  Counterfeit      thejuicedoctor   Depends
# 9              $600.00  Counterfeit           sexyhomer   Illegal
# 10           $5,000.00  Counterfeit          stevemeds1   Illegal
# 11              $79.96  Counterfeit          Rammstein   Illegal
# 12          $10,000.00  Counterfeit         biochemshop   Illegal
# 13             $500.00  Counterfeit         timmiroll56   Illegal
# 14           $1,000.00  Counterfeit         timmiroll56   Illegal
# 15              $24.99  Counterfeit           GoldApple   Illegal
# 16             $100.00  Counterfeit        namedeclined   Illegal
# 17              $50.00  Counterfeit        namedeclined   Illegal
# 18             $276.35  Counterfeit      thejuicedoctor   Depends
# 19             $288.54  Counterfeit      thejuicedoctor   Depends
# 20             $600.00  Counterfeit               ytuiv   Illegal
# 21             $250.00  Counterfeit               Hazzy   Depends
# 22             $250.00  Counterfeit               Hazzy   Depends
# 23             $176.90        Drugs       CaesarsPalace   Illegal
# 24             $201.00        Drugs           Safeserve   Illegal
# 25             $571.85        Drugs            XanaxNDD   Illegal
# 26             $201.00        Drugs         dopekingusa   Illegal
# 27             $128.60        Drugs      themushroomman   Illegal
# 28             $400.00        Drugs              seller   Illegal
# 29           $7,537.89        Drugs           sweetyman   Illegal
# 30             $170.00        Drugs          TheSpecial   Illegal
# 31             $554.00        Drugs       TheodorMorell   Illegal
# 32          $68,445.00        Drugs           drugshub1   illegal
# 33              $10.00        Drugs         Prosperity1   Illegal
# 34       $170 for 50p.       Drugs        Freewaybogez    Illegal
# 35              $10.18  Electronics      HappyShopOrigi   Illegal
# 36              $33.94  Electronics       SpongebobShop   Illegal
# 37              $65.00  Electronics               Hazzy   Depends
# 38             $120.00  Electronics               Hazzy   Depends
# 39              $12.10        Fraud          KingKongCC   Illegal
# 40              $15.10        Fraud            drhack3r   Illegal
# 41              $10.05        Fraud          fraudbuddy   Depends
# 42              $15.10        Fraud       smart666tiger   Illegal
# 43              $19.10        Fraud       smart666tiger   Illegal
# 44               $9.05        Fraud           topkittzz   Illegal
# 45              $10.05        Fraud           topkittzz   Illegal
# 46               $4.05        Fraud           topkittzz   Illegal
# 47             $110.55        Fraud             trustar   Illegal
# 48              $72.82        Fraud           Rammstein   Depends
# 49             $600.00        Fraud         timmiroll56   Illegal
# 50               $9.99        Fraud           GoldApple   Illegal
# 51               $9.99        Fraud           GoldApple   Illegal
# 52              $13.70        Fraud      HappyShopOrigi   Depends
# 53              $16.00        Fraud               Rambe   Illegal
# 54              $10.00        Fraud           topkittzz   Illegal
# 55               $3.05        Guide         sixandeight   Depends
# 56               $3.05        Guide         sixandeight   Depends
# 57              $10.05        Guide       smart666tiger   Depends
# 58               $2.05        Guide           superhero   Depends
# 59               $7.05        Guide           topkittzz   Depends
# 60               $3.05        Guide           topkittzz   Depends
# 61               $2.49        Guide           Legendary   Depends
# 62               $4.00        Guide            Onepiece   Depends
# 63             $386.67        Guide            Fraudway   Depends
# 64               $2.58        Guide            Fraudway   Depends
# 65               $2.99        Guide         HarleyQuinn   Depends
# 66              $10.00        Guide        trusteelucky   Depends
# 67               $3.50        Guide       DarknetWizard   Depends
# 68               $3.00        Guide            katarina   Illegal
# 69        CAD $75.0225        Guide               joker   Depends
# 70             CAD $21        Guide         lordfinnese   Depends
# 71              $50.04       Metals          futuremeds   Depends
# 72  1$ per single bill       Metals          anonsheep    Illegal
# 73             CAD $63       Metals       gracepapineau   Depends
# 74          $50,251.05     Services          fraudbuddy   Illegal
# 75               $9.99     Services           GoldApple   Depends
# 76               $6.00     Services         socialmedia   Depends
# 77           CAD $7.35     Services         canadapilot   Depends
# 78           CAD $4.20     Services     thepirateisland   Depends
# 79             $100.50     Software          fraudbuddy   Illegal
# 80               $4.05     Software           sweatless   Depends
# 81               $5.95     Software      HappyShopOrigi   Depends
# 82               $1.85     Software            Fraudway   Depends
# 83              $12.50     Software            Fraudway   Depends
# 84               $2.99     Software         HarleyQuinn   Illegal
# 85               $2.99     Software         HarleyQuinn   Depends
# 86               $3.99     Software         HarleyQuinn   Depends
# 87             $990.00     Software               g3cko     Legal
# 88               $2.08     Software               g3cko   Illegal
# 89               $2.00     Software               g3cko   Illegal
# 90               $2.99     Software     DangerousTomato   Depends
# 91               $1.36     Software      heartkidnapper   Depends
# 92               $9.86     Software           topkittzz   Depends
# 93        CAD $20.9895     Software             pegasus   Illegal
# 94             CAD $63     Software  thedangeroustomato   Depends
# 95               $2.99      Weapons         HarleyQuinn   Illegal
# 96              $10.00      Weapons    Napoleonbonapart   Illegal
# 97               $2.99      Weapons  TheDangerousTomato   Depends
# 98              $25.00      Weapons       TheFreelancer   Depends
# 99               $4.15     software               g3cko   Illegal
#
#                                                                                                                                                    Additional Notes  \
# 0                                                                                                                                 illegal if the account was stolen
# 1                                                                                                           account accessed without consent from the account owner
# 2                                                                                                           account accessed without consent from the account owner
# 3   would only be used to pretend that user is vaccinated in places where it was needed (like travel thru international borders...no jurisdiction would be pleased)
# 4                                                                                                                                                               NaN
# 5                                                                                        having it probably isn't legal (unsure) but using it to help fake an ID is
# 6                                                                                                                                                               NaN
# 7                                                                                               template fillable by buyer that then allows impersonation of police
# 8                                It's clearly stated that it's counterfeit, but the intention may be to resell it as real. Also it might be copyright infringement.
# 9                                                                  advertises that it comes with Rolex box and certificate, but at price point it is fake-copyright
# 10                                                                                                    advertises as a real Audemars but is a reproduction-copyright
# 11                                                                                                                                                              NaN
# 12                                                                                                                                                              NaN
# 13                                                                                                                                                              NaN
# 14                                                                                                                                                              NaN
# 15                                                                                                                 allows false prescriptions to be filled, i think
# 16                                                                                                             made-to-order university diploma bachelor,master,phD
# 17                                                                                                   fake cable bill that can be used for proof of address/spending
# 18                                                                                          advertises as replica but customer would likely present it as real item
# 19                                                                      advertises as replica but comes with the box and certificates authenticating its legitimacy
# 20                                                                                                        reproduced passport for a variety of countries on request
# 21                                                                                   advertised as a replica, but customer could intent to resell it as a real item
# 22                                                                                   advertised as a replica, but customer could intent to resell it as a real item
# 23                                                                                                                                                              NaN
# 24                                                                                                                                                              NaN
# 25                                                                                                                           prescription drug without prescription
# 26                                                                                                                                                              NaN
# 27                                                                                                                                                              NaN
# 28                                                                                                                                          set for producing drugs
# 29                                                                                                                                                              NaN
# 30                                                                                                                                                            drugs
# 31                                                                                                                                                              NaN
# 32                                                                                                                                                              NaN
# 33                                                                                                                                                              NaN
# 34                                                                         Adderall cannot be sold without prescription for ADHD/ADD or other types of pathologies
# 35                                                                                                                           credit card with fake name and address
# 36                                                                                              advertises that the codes for the cards are sent via chat-copyright
# 37                                                                     patent infringement but labelled as replica, customer would likely present it as a real item
# 38                                                                                   advertised as a replica, but customer could intent to resell it as a real item
# 39                                                                                                    allows for fake proof of address or financial asset reporting
# 40                                                                                                                                                              NaN
# 41                                                       may be hijacked account without consent or may be created falsely (but service likely not paid regardless)
# 42                                                                                                                                                              NaN
# 43                                                                                                                     allows non-user admin access without consent
# 44                                                                                                                                                       no consent
# 45                                                                                                                                   allows for fraudulent payments
# 46                                                                                                Cards most likely issued nameless or in fake names illegitimately
# 47                                                      Although it is advertised as fake so could be depends, the posession of false identity documents is illegal
# 48                                                                                 - depends on the intention; Owning one isnt setting it up to steal packages is.
# 49                                                                                                                                                              NaN
# 50                                                                voters did not consent for this information to be sold (and there is a LOT of information listed)
# 51                                                              birth records sold without people's consent, can be used to reissue identity documents fraudulently
# 52                                                                                                                 large limit credit card available for a pittance
# 53                                                                               Appears to be using an established account w/o owners consent based on description
# 54                                                                                                           photoshop template for customer to fill with bogus SSN
# 55                                                                                   guide may not be illegal but the methods and goal of the user of the guide are
# 56                                                                                   guide may not be illegal but the methods and goal of the user of the guide are
# 57                                                                                                                    depends on the methods used to make the money
# 58                                                                                                   illegal if you intent to follow it to try to escape the police
# 59                                                                              guide may not be illegal but the methods and goal of the user of the guide could be
# 60                                                                                                fine as long as you don't actually make/use/sell resulting drugs
# 61                                                                                               guide itself may not be illegal but the methods illustrated may be
# 62                                                                                              guide itself may not be illegal but the use afterwards of spying is
# 63                                                                                                                           illegal if you use what you are taught
# 64                                                                                                                                        not illegal to just learn
# 65                                                                                                                        legal as long as you don't make any drugs
# 66                                                                                                                                        not illegal to just learn
# 67                                                                                                              could be illegal depending on the methods presented
# 68                                  emails are personally identifiable information, for which no consent is given by the owners of the email addresses to be shared
# 69                                                   a guide on its own wouldnt be illegal, guide on how to refund ordered items while keeping and seeling the item
# 70                                                       just knowing how towouldn't be illegal, guide on how to set up drop adresses for purchases on black market
# 71                                                                   depends on the source of the gold. also weird that the product description only included drugs
# 72                                                                   You cannot use those to make your own sample packs and distribute them, commercially or free.
# 73                                                                                            depends of the source of the silver, obviously illegal if it's stolen
# 74                                                                                                                                               Market maniplation
# 75                                                            numbers, if legitimate, were not given with users consent. probably used for farming data or phishing
# 76                                                                 if the followers are actual accounts then it's done without accountholder's consent, most likely
# 77                                                                                                         legal if done to self, sends 1000 emails where requested
# 78                                                                                       against the terms of service, could be illegal if stolen accounts are used
# 79                                                                                              impersonation of other people/entities without knowledge or consent
# 80                                                                                     tool may be used maliciously or could be used legitimately (more likely not)
# 81                                                      Brute forcing a password is illegal but if for the purposes of testing with the person's consent perhaps ok
# 82                                                                                                                                          ok if used consensually
# 83                                                                                                                                                   illegal to use
# 84                                                                                                                                                              NaN
# 85                                                                                                          if not use on non-consenting party than it should be ok
# 86                                                                                                                   legal as long as you use the code consensually
# 87                                                                                                                   software to do automated forex trading for you
# 88                                                                                                                    tracks info on other players for online poker
# 89                                                                                                                                                  stolen services
# 90                                                                                                its illegal if you use it on people without getting their consent
# 91                                                                                    depends if the buyer intends to actually use it for malicious purposes or not
# 92                                                                                    depends if the buyer intends to spread it to computers without consent or not
# 93                                                                                                                                                              NaN
# 94                                                       if never used on an unconsenting person then it should be ok, code and instructions for ransomware attacks
# 95                                                                                                                                                              NaN
# 96                                                                                                                                          unlicensed gun sellling
# 97                                                                                                 illegal if the customer actually decides to make and use the gun
# 98                                                                                                 illegal if the customer actually decides to make and use the gun
# 99                                                                                                                          virus for intercepting BTC transactions
#
#                Site
# 0       ASAP market
# 1          Tor2door
# 2          Tor2door
# 3       ASAP market
# 4       ASAP market
# 5       ASAP market
# 6       ASAP market
# 7       ASAP market
# 8       ASAP market
# 9           DarkFox
# 10          DarkFox
# 11         DarkFox
# 12     Quest Market
# 13     Quest Market
# 14     Quest Market
# 15         Tor2door
# 16         Tor2door
# 17         Tor2door
# 18         Tor2door
# 19         Tor2door
# 20         Tor2door
# 21       WeTheNorth
# 22       WeTheNorth
# 23      ASAP market
# 24      ASAP market
# 25      ASAP market
# 26      ASAP market
# 27      ASAP market
# 28   Courier Market
# 29         DarkFox
# 30        Incognito
# 31        Incognito
# 32        Incognito
# 33       WeTheNorth
# 34  Tor2door Market
# 35          DarkFox
# 36          DarkFox
# 37       WeTheNorth
# 38       WeTheNorth
# 39      ASAP market
# 40      ASAP market
# 41      ASAP market
# 42      ASAP market
# 43      ASAP market
# 44      ASAP market
# 45      ASAP market
# 46      ASAP market
# 47      ASAP market
# 48          DarkFox
# 49     Quest Market
# 50         Tor2door
# 51         Tor2door
# 52         Tor2door
# 53         Tor2door
# 54         Tor2door
# 55      ASAP market
# 56      ASAP market
# 57      ASAP market
# 58      ASAP market
# 59      ASAP market
# 60      ASAP market
# 61          DarkFox
# 62          DarkFox
# 63     Quest Market
# 64     Quest Market
# 65     Quest Market
# 66     Quest Market
# 67         Tor2door
# 68         Tor2door
# 69       WeTheNorth
# 70       WeTheNorth
# 71          DarkFox
# 72  Tor2door Market
# 73       WeTheNorth
# 74      ASAP market
# 75         Tor2door
# 76         Tor2door
# 77       WeTheNorth
# 78       WeTheNorth
# 79      ASAP market
# 80      ASAP market
# 81          DarkFox
# 82     Quest Market
# 83     Quest Market
# 84     Quest Market
# 85     Quest Market
# 86     Quest Market
# 87     Quest Market
# 88     Quest Market
# 89     Quest Market
# 90         Tor2door
# 91         Tor2door
# 92         Tor2door
# 93       WeTheNorth
# 94       WeTheNorth
# 95       WeTheNorth
# 96       WeTheNorth
# 97       WeTheNorth
# 98       WeTheNorth
# 99     Quest Market

# %% [markdown]
# ### Determine the three products that made you the most suprised
#
# Most of the products in the list are pretty ordinary, things you would expect to see on a black market. Then there are a lot of products that fall in categories you wouldn't necessarily expect to see in a black market, but it still appears a lot. Finally, there is a small subgroup of products which even on the black market appear only once or twice. This category contains the three items that we were most suprised by.
#
# Our top three of most suprising posts are:
#
# - **R.A.T. Setup and Mentoring Service - Make Money. Fast. Simple.:** This was surprising because it was not expected that someone on one of the darkmarket sites would be offering to actively teach a person as well as offering to give follow up help for some time after.
# - **YOUTUBE: How To Become Rich || HQ eBook With ECourses:** This post seems peculiar, because if such a guide is uploaded to YouTube, it most likely doesn't contain any illegal methods, since that is against the ToS of YouTube. But if it doesn't contain any illegal methods, why would it be on the black market? What is the difference between this and any other (public) guide or video on YouTube that explains ways on how to get rich.
# - **Forged Xfinity Comcast Statement:** On first sight, this makes no sense. You would think an official statement from Xfinity or Comcast would we useless. But this can actually be used to prove to the respective company that you own, live at or in any other way are affiliated with the address listed on the statement. This can then be used to impersonate the house owner.

# %% [markdown]
# ### Import and show the sellers table

# %%
sf = pd.read_csv('sellers.csv')

# Sort by the amount of posts and rating
sf = sf.sort_values(by = ['Amount of posts'], ascending = False)

# Reset the index column
sf.reset_index(drop = True, inplace = True)
sf
# Out:
#                   Name  Amount of posts      Rating  Low price ($)  \
# 0      DangerousTomato             2235         64%           2.00
# 1          prettypacks             1667         99%          50.00
# 2          HarleyQuinn              450  no reviews           1.00
# 3          timmiroll56              415        100%         500.00
# 4                g3cko              282        100%           1.00
# 5             Fraudway              251        100%           1.72
# 6           fraudbuddy              187         80%          50.00
# 7            GoldApple              150         94%           1.00
# 8         trusteelucky              148         96%          10.00
# 9       HappyShopOrigi              121         80%           1.00
# 10        digitalworld              120         94%           3.00
# 11  thedangeroustomato              100         98%           6.00
# 12         biochemshop               97         91%           8.00
# 13        namedeclined               78        100%          20.00
# 14      thejuicedoctor               62         99%         150.00
# 15         lordfinnese               42         93%          20.00
# 16       gracepapineau               38         98%           7.00
# 17     thepirateisland               38        100%           7.00
# 18             pegasus               37         85%          10.00
# 19               joker               17         91%          10.00
# 20              seller               12         50%           0.01
# 21         canadapilot                5        100%           7.00
#
#     High price ($)               Primary category            Site
# 0                5             Fraud and Software        Tor2door
# 1              500                          Drugs     ASAP market
# 2               45             software and guids    Quest Market
# 3             2000   counterfeit, fraud and drugs    Quest Market
# 4              990            software and guides    Quest Market
# 5              387            software and guides    Quest Market
# 6            50000                    Counterfeit     ASAP market
# 7               25             Fraud and Software        Tor2door
# 8              100                fraud and guids    Quest Market
# 9               20             Fraud and Software        Tor2door
# 10              10          Software and accounts        Tor2door
# 11              52                fraud and guids      WeTheNorth
# 12           10000          counterfeit and drugs    Quest Market
# 13             800         Fraud, Software, Drugs        Tor2door
# 14             250                    Counterfeit     ASAP market
# 15             727                fraud and guids      WeTheNorth
# 16            1000                fraud and guids      WeTheNorth
# 17             315  digital products and services      WeTheNorth
# 18             103      fraud, software and guids      WeTheNorth
# 19            1050                fraud and guids      WeTheNorth
# 20            3000         porn and illegal items  Courier Market
# 21              52                       services      WeTheNorth

# %% [markdown]
# ### Determine the top 10 sellers

# %%
sf['Estimated revenue'] = sf['Amount of posts'] * sf['Low price ($)']
top10 = sf.sort_values(by = ['Estimated revenue'], ascending = False)
top10 = top10.head(10)
top10.reset_index(drop = True, inplace = True)
top10
# Out:
#                  Name  Amount of posts Rating  Low price ($)  High price ($)  \
# 0         timmiroll56              415   100%          500.0            2000
# 1         prettypacks             1667    99%           50.0             500
# 2          fraudbuddy              187    80%           50.0           50000
# 3      thejuicedoctor               62    99%          150.0             250
# 4     DangerousTomato             2235    64%            2.0               5
# 5        namedeclined               78   100%           20.0             800
# 6        trusteelucky              148    96%           10.0             100
# 7         lordfinnese               42    93%           20.0             727
# 8         biochemshop               97    91%            8.0           10000
# 9  thedangeroustomato              100    98%            6.0              52
#
#                Primary category          Site  Estimated revenue
# 0  counterfeit, fraud and drugs  Quest Market           207500.0
# 1                         Drugs   ASAP market            83350.0
# 2                   Counterfeit   ASAP market             9350.0
# 3                   Counterfeit   ASAP market             9300.0
# 4            Fraud and Software      Tor2door             4470.0
# 5        Fraud, Software, Drugs      Tor2door             1560.0
# 6               fraud and guids  Quest Market             1480.0
# 7               fraud and guids    WeTheNorth              840.0
# 8         counterfeit and drugs  Quest Market              776.0
# 9               fraud and guids    WeTheNorth              600.0

# %% [markdown]
# ### Determine which 3 sellers should be reported to the police
#
# Fraud and counterfeit could be very harmful to others, so the worst sellers probably sell products in this category. Malware is also a big thing which could lead to fraud.
#
# The 3 sellers which sell the most of these products and thus we think should be reported to the police are:
# - **timmiroll56** on Quest Market
# - **DangerousTomato** on Tor2door
# - **namedeclined** on Tor2door
#
# We believe that these are the worst sellers within our results. Shutting down these sellers would remove a lot of fraud from the black market, which in turn makes it so that less people are victim of fraud.

# %% [markdown]
# # Conclusion
#
# In conclusion, we have found a very wide selection of different items in very different price ranges from an assortment of sellers that seem to specialize in multiple categories, with the most surprising ones being the things that seemed to be the most out of place. The black markets seam to be just be lowly regulated online marketplaces where yo can look for or offer nealy any service and if one site won't allow you to sell what you want you can just find one that will. While not everything sold on the sites are inherantly illegal many things are and most of what isn't is likely to be used illegally.
